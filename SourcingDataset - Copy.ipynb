# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
data = pd.read_csv("C:\\Users\\27797\\OneDrive\\Documents\\Finance_data.csv")

# %%
data.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
# Check for missing values
print(data.isnull().sum())

# Get data types and summary statistics
print(data.info())
print(data.describe())
# Out:
# gender                               0
# age                                  0
# Investment_Avenues                   0
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64
# ...

# %%
# Fill missing values only in numeric columns with the median
numeric_cols = data.select_dtypes(include=['float64', 'int64']).columns
data[numeric_cols] = data[numeric_cols].fillna(data[numeric_cols].median())
# Display the first few rows to verify the changes
data.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
# Fill missing values in categorical columns with the most frequent value (mode)
categorical_cols = data.select_dtypes(include=['object']).columns
data[categorical_cols] = data[categorical_cols].fillna(data[categorical_cols].mode().iloc[0])
data.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
# Check the data types of each column
print(data.dtypes)
# Out:
# gender                               object
# age                                   int64
# Investment_Avenues                   object
# Mutual_Funds                          int64
# Equity_Market                         int64
# Debentures                            int64
# Government_Bonds                      int64
# Fixed_Deposits                        int64
# PPF                                   int64
# Gold                                  int64
# Stock_Marktet                        object
# Factor                               object
# Objective                            object
# Purpose                              object
# Duration                             object
# Invest_Monitor                       object
# Expect                               object
# Avenue                               object
# What are your savings objectives?    object
# Reason_Equity                        object
# Reason_Mutual                        object
# ...

# %%
# Check the shape of the dataset (rows, columns)
print(data.shape)
# Out:
# (40, 24)

# %%
# Convert categorical columns to dummy variables (one-hot encoding)
data = pd.get_dummies(data, drop_first=True)

# %%
data.head()
# Out:
#    age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# 0   34             1              2           5                 3
# 1   23             4              3           2                 1
# 2   30             3              6           4                 2
# 3   22             2              1           3                 7
# 4   24             2              1           3                 6
#
#    Fixed_Deposits  PPF  Gold  gender_Male  Investment_Avenues_Yes  ...  \
# 0               7    6     4        False                    True  ...
# 1               5    6     7        False                    True  ...
# 2               5    1     7         True                    True  ...
# 3               6    4     5         True                    True  ...
# 4               4    5     7        False                   False  ...
#
#    Reason_Equity_Liquidity  Reason_Mutual_Fund Diversification  \
# 0                    False                               False
# ...

# %%
#Finance Dataset: This dataset probably contains financial information, possibly related to income, expenses, savings,
#and other financial metrics. It could help in modeling consumer behavior, financial planning, and understanding resource allocation needs.

#Why this dataset?
#Financial data can be used for time-series forecasting (predicting future trends like revenue, expenses, etc.) and risk management.
#The dataset allows you to identify patterns and segment financial decisions into short-term (monthly or quarterly) and long-term (annual or beyond) financial planning, aligning with the two-pot system.

# %%
#How it relate to the Two-pot System
#Manage short-term finances, such as monthly income, expenses, and debt repayment.
#This dataset helps in identifying areas where immediate resource allocation (like paying off short-term debt) is required.

# %%
#THe reason i commented my answers it was giving me error if i remove them!!!

# %%
# Encode categorical variables if necessary
label_encoders = {}
for column in data.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column] = le

# %%
data.head()
# Out:
#    age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# 0   34             1              2           5                 3
# 1   23             4              3           2                 1
# 2   30             3              6           4                 2
# 3   22             2              1           3                 7
# 4   24             2              1           3                 6
#
#    Fixed_Deposits  PPF  Gold  gender_Male  Investment_Avenues_Yes  ...  \
# 0               7    6     4        False                    True  ...
# 1               5    6     7        False                    True  ...
# 2               5    1     7         True                    True  ...
# 3               6    4     5         True                    True  ...
# 4               4    5     7        False                   False  ...
#
#    Reason_Equity_Liquidity  Reason_Mutual_Fund Diversification  \
# 0                    False                               False
# ...

# %%
# Replace 'CorrectColumnName' with the actual column name you identified
target_column = 'Purpose_Savings for Future'  # Adjust this based on your selection

# Define the features and target variable
if target_column in data.columns:
    # Example: Plotting 'age' against 'Purpose_Savings for Future'
    plt.figure(figsize=(10, 6))
    sns.countplot(data=data, x='age', hue=target_column)
    plt.title('Count of Savings Purpose by Age')
    plt.xlabel('Age')
    plt.ylabel('Count')
    plt.legend(title=target_column)
    plt.xticks(rotation=45)
    plt.show()
else:
    raise KeyError(f"The specified target column '{target_column}' does not exist in the dataset.")

# %%
# Visualization of the segmented data
sns.countplot(data=data, x='age', hue='Purpose_Savings for Future')
plt.title('Segmentation of Savings Purpose by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Purpose of Savings')
plt.show()

# %% [markdown]
# Age Distribution:
#
# The graph shows a wide range of ages from 21 to 35, with varying counts for individuals who plan to save for the future (indicated by the orange bars) and those who do not (indicated by the blue bars).
# Trends:
#
# The highest count of individuals saving for the future appears to be around the age of 25, suggesting that employees at this age are more likely to consider saving for future purposes.
# The count of employees not saving for the future is generally higher in the younger age groups (21-24) compared to older age groups.
# Implications:
#
# Younger employees (21-24) seem to have less inclination towards saving for future purposes, which could indicate a lack of awareness about the importance of savings or a belief that they can defer savings for later.
# As age increases, particularly at 25 and 26, there is a noticeable increase in the number of employees considering saving, which could reflect a shift in priorities as individuals mature in their careers and personal lives.
